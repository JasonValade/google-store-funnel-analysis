# %% [markdown]
# # Purchase prediction (interpretable)
#
# This notebook trains an interpretable logistic regression model to predict whether a user will purchase.
#
# Instructions:
# 1. Export `model_features` from BigQuery (see sql/07_model_features.sql) to `data/processed/model_features.csv`.
# 2. Update the file path below and run the notebook.
#
# Do not begin modeling until the funnel analysis is validated. This notebook contains placeholder cells and guidance for reproducible modeling.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, precision_score, recall_score, f1_score, confusion_matrix

# Replace with your exported CSV path
model_features_path = 'data/processed/model_features.csv'
# df = pd.read_csv(model_features_path)

print('Do NOT begin modeling until user-level and session-level funnels are validated. Run sql/07_model_features.sql with an explicit observation window and export model_features.csv to data/processed/ or data/processed/demo/. Update this path and then run modeling cells.')
